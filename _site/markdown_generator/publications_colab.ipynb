# %% [markdown]
# # Publications markdown generator (Google Colab)
#
# Ini notebook meniru fungsi `publications.py`, tetapi dioptimalkan untuk Colab dengan input `publications2.csv`.
#
# Langkah: upload CSV, jalankan sel, hasil akan dibuat dalam `_publications/` dan dapat diunduh.

# %%
# 1) Upload file CSV (publications2.csv) dari lokal ke Colab
from google.colab import files
uploaded = files.upload()
if 'publications2.csv' not in uploaded:
    raise FileNotFoundError('Please upload publications2.csv')
print('Uploaded:', list(uploaded.keys()))

# %%
import pandas as pd
import os

# 2) Baca data di publications2.csv (CSV standar, koma delimiter)",
,
]},{
:
,
:null,
:{},
:[],
:[
3
,
code

# 4) Generate markdown files ke folder _publications",
,
,
,
,
,
,
,
,
,
,
,
venue: '{html_escape(venue)}'
,
,
,
,
citation: '{html_escape(citation)}'
,
,
,
,
]},{
:
,
:null,
:{},
:[],
:[
5
,
-1
20
]},{
:
,
:null,
:{},
:[],
:[
6
,
,
,
]}],
:{
:{
:
,
:[],
:[]},
:{
:
,
:
3
},
:{
:
}},
:4,
:0}
